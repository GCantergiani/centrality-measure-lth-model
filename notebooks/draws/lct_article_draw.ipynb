# %%
# %matplotlib inline 

import networkx as nx
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
G=nx.chordal_cycle_graph(200)
nx.draw(G, edge_color='w', node_size = 30)

# %%
G=nx.chordal_cycle_graph(100)
nx.draw(G, edge_color='w', node_size = 20)
G=nx.lollipop_graph(50,5)
nx.draw(G, edge_color='w', node_size = 20)
G=nx.lollipop_graph(50,5)
nx.draw(G, edge_color='w', node_size = 20)

# %%
G=nx.chordal_cycle_graph(100)
nx.draw(G, edge_color='w', node_size = 20)
G=nx.complete_graph(50)
nx.draw(G, edge_color='w', node_size = 30)

# %%
G=nx.circular_ladder_graph(100)
nx.draw(G, edge_color='w', node_size = 30)
G=nx.circular_ladder_graph(100)
nx.draw(G, edge_color='w', node_size = 30)
