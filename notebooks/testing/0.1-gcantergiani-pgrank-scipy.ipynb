# %%
# %matplotlib inline  

import networkx as nx
import matplotlib.pyplot as plt

# %%
G = nx.complete_graph(5)
G = G.to_directed()

# %%
nx.draw(G)

# %%
nx.pagerank_scipy(G,tol=1e-10)
# Out:
# {0: 0.2, 1: 0.2, 2: 0.2, 3: 0.2, 4: 0.2}
